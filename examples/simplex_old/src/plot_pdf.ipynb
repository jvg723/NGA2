# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Set paths to file location
data_path_Run1="/Users/josephgiliberto/Builds/NGA2/examples/simplex_old/pdf_data/Run1.csv"

# Import data_01
df = pd.read_csv("/Users/josephgiliberto/Builds/NGA2/examples/simplex_old/pdf_data/Run1.csv")
print(df.info())
# data_01=pd.read_csv({'diameter':np.genfromtxt(data_path_Run1,skip_header=2,usecols=3),
#                       'volume':np.genfromtxt(data_path_Run1,skip_header=2,usecols=4)})
#                    'time_step_size':np.genfromtxt(data_path_01,skip_header=2,usecols=2),
#                    'Pmax':np.genfromtxt(data_path_01,skip_header=2,usecols=7),
#                    'vof_integral':np.genfromtxt(data_path_01,skip_header=2,usecols=8),
#                    'vof_removed':np.genfromtxt(data_path_01,skip_header=2,usecols=9)})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
# # Plotting
# plt.figure(figsize=(12, 6))
# plt.subplot(2, 1, 1)
# plt.plot(data_01.diameter, data_01.volume)
# # plt.title('VOF Integral vs Time')
# plt.xlabel('Diameter (um)')
# plt.ylabel('Volume Distribution')
# # plt.legend()
# print(data_01.diameter)
